# %% [markdown]
# # 01 - Exploration Notebook
# Initial profiling and quality checks of the Olist dataset.

# %%
import pandas as pd

df = pd.read_csv("../data_raw/olist_customers_dataset.csv")
df.head()
